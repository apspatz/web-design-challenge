# %%
import pandas as pd

distfile = "../resources/district_crime.csv"
typefile = "../resources/crime_type.csv"

district = pd.read_csv(distfile)
types = pd.read_csv(typefile)

# %%
district_df = district.set_index('district')
district_df.head()
# Out:
#               description  count
# district
# Downtown     Other crimes    145
# Downtown  Deceased Person     34
# Downtown   Missing Person     31
# Downtown          Assault     20
# Downtown        Sex crime     15

# %%
district_html = district_df.to_html()
district_html.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>description</th>      <th>count</th>    </tr>    <tr>      <th>district</th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Downtown</th>      <td>Other crimes</td>      <td>145</td>    </tr>    <tr>      <th>Downtown</th>      <td>Deceased Person</td>      <td>34</td>    </tr>    <tr>      <th>Downtown</th>      <td>Missing Person</td>      <td>31</td>    </tr>    <tr>      <th>Downtown</th>      <td>Assault</td>      <td>20</td>    </tr>    <tr>      <th>Downtown</th>      <td>Sex crime</td>      <td>15</td>    </tr>    <tr>      <th>North</th>      <td>Other crimes</td>      <td>157</td>    </tr>    <tr>      <th>North</th>      <td>Deceased Person</td>      <td>88</td>    </tr>    <tr>      <th>North</th>      <td>Missing Person</td>      <td>80</td>    </tr>    <tr>      <th>North</th>      <td>Assault</td>      <td>37</td>    </tr>    <tr>      <
# ...

# %%
types_df = types.set_index('description')
types_df
# Out:
#                   district  count
# description
# Assault          Southeast     57
# Assault          Northeast     39
# Assault              North     37
# Assault           Downtown     20
# Assault          Southwest     19
# Assault          Northwest      9
# Deceased Person      North     88
# Deceased Person  Northeast     75
# Deceased Person  Northwest     64
# Deceased Person  Southwest     58
# Deceased Person  Southeast     55
# Deceased Person   Downtown     34
# Missing Person   Southeast    131
# Missing Person   Northeast     91
# Missing Person       North     80
# Missing Person   Southwest     50
# Missing Person    Downtown     31
# Missing Person   Northwest     25
# Other crimes     Southeast    174
# Other crimes         North    157
# Other crimes      Downtown    145
# Other crimes     Northwest    135
# Other crimes     Southwest    130
# Other crimes     Northeast    100
# Sex crime        Southeast     28
# Sex crime        Northeast     22
# ...

# %%
types_html = types_df.to_html()
types_html.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>district</th>      <th>count</th>    </tr>    <tr>      <th>description</th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Assault</th>      <td>Southeast</td>      <td>57</td>    </tr>    <tr>      <th>Assault</th>      <td>Northeast</td>      <td>39</td>    </tr>    <tr>      <th>Assault</th>      <td>North</td>      <td>37</td>    </tr>    <tr>      <th>Assault</th>      <td>Downtown</td>      <td>20</td>    </tr>    <tr>      <th>Assault</th>      <td>Southwest</td>      <td>19</td>    </tr>    <tr>      <th>Assault</th>      <td>Northwest</td>      <td>9</td>    </tr>    <tr>      <th>Deceased Person</th>      <td>North</td>      <td>88</td>    </tr>    <tr>      <th>Deceased Person</th>      <td>Northeast</td>      <td>75</td>    </tr>    <tr>      <th>Deceased Person</th>      <td>Northwest</td>      <td>64</td>    </tr>    <tr>      <th>Deceas
# ...
